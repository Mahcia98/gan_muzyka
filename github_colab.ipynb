# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/github/gan_muzyka/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/github/gan_muzyka

# %%
# %mkdir github
# %cd /content/drive/MyDrive/github/
# ls
# Out:
# /content/drive/MyDrive/github

# %%
# !git config --global user.email "martsta077@student.polsl.pl"
# !git config --global user.name "Mahcia98"

# %%
git_token='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'
user = "Mahcia98"
repo = "gan_muzyka"
# !git clone https://{git_token}@github.com/{user}/{repo}.git
# Out:
# Cloning into 'gan_muzyka'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 160 (delta 22), reused 45 (delta 17), pack-reused 110
# Receiving objects: 100% (160/160), 55.95 KiB | 2.54 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !git add github_colab.ipynb
# !git commit -m "add github colab"
# !git push -u origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@fd06586ed239.(none)')
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
